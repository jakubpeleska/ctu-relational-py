# %%
# %load_ext autoreload
# %autoreload 2

import ctu_relational
from relbench import datasets

# %%
dataset = ctu_relational.datasets.CTUDataset("legalActs")

db = dataset.get_db(False)
# Out:
# Making Database object from scratch...
# (You can also use `get_dataset(..., download=True)` for datasets prepared by the RelBench team.)
# ...
# {'krk': []}
# Done in 0.16 seconds.

# %%
print(db.table_dict["krk"].df["class"].value_counts())
print({n: t.fkey_col_to_pkey_table for n, t in db.table_dict.items()})
# Out:
# class
# legal      658
# illegal    342
# Name: count, dtype: Int64
# {'krk': {}}

# %%
import pandas as pd

pd.concat()
